# %% [markdown]
# Lets build a model!

# %%
# !wget https://download.blender.org/release/Blender2.82/blender-2.82a-linux64.tar.xz blender-2.82a-linux64.tar.xz
# Out:
# --2020-04-02 16:41:21--  https://download.blender.org/release/Blender2.82/blender-2.82a-linux64.tar.xz
# Resolving download.blender.org (download.blender.org)... 82.94.213.221
# Connecting to download.blender.org (download.blender.org)|82.94.213.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134381616 (128M) [application/octet-stream]
# Saving to: ‘blender-2.82a-linux64.tar.xz’
#
# blender-2.82a-linux 100%[===================>] 128.16M  3.65MB/s    in 85s
#
# 2020-04-02 16:42:47 (1.50 MB/s) - ‘blender-2.82a-linux64.tar.xz’ saved [134381616/134381616]
#
# --2020-04-02 16:42:47--  http://blender-2.82a-linux64.tar.xz/
# Resolving blender-2.82a-linux64.tar.xz (blender-2.82a-linux64.tar.xz)... failed: Name or service not known.
# wget: unable to resolve host address ‘blender-2.82a-linux64.tar.xz’
# FINISHED --2020-04-02 16:42:47--
# Total wall clock time: 1m 26s
# Downloaded: 1 files, 128M in 1m 25s (1.50 MB/s)

# %%
# !sudo docker build --tag odin ./
# Out:
# [sudo] password for chris:

# %%
# !sudo docker stop odin-container
# Out:
# odin-container

# %%
AWS_ACCESS_KEY_ID='<update_this_value>'
AWS_SECRET_ACCESS_KEY='<update_this_value>'

bucket="3m-s3-data-sharing-bucket"
S3_prefix_three_d_object="skidsteer.obj"
S3_prefix_background='background.pck'
theta='180'
output='output'

# %%
# !sudo docker run --rm --publish 8080:8080/tcp -e AWS_ACCESS_KEY_ID=$AWS_ACCESS_KEY_ID -e AWS_SECRET_ACCESS_KEY=$AWS_SECRET_ACCESS_KEY --name odin-container odin serve $bucket $S3_prefix_three_d_object $S3_prefix_background $theta $output
# Out:
# Blender 2.82 (sub 7) (hash 375c7dc4caf4 built 2020-03-12 05:30:40)
# found bundled python: /blender-2.82a-linux64/2.82/python
# Info: Deleted 1 object(s)
# Fra:1 Mem:115.51M (0.00M, Peak 158.88M) | Time:00:00.08 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | text
# Fra:1 Mem:135.55M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:1 Mem:117.13M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Waiting for render to start
# Fra:1 Mem:117.15M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:117.15M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Scene
# Fra:1 Mem:117.15M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Shaders
# ...

# %%
# !../blender-2.82a-linux64/blender -b -noaudio -E CYCLES --python script3.py "3m-s3-data-sharing-bucket" "skidsteer.obj" 'background.pck' '180' 'output'
# Out:
# Blender 2.82 (sub 7) (hash 375c7dc4caf4 built 2020-03-12 05:30:40)
# found bundled python: /home/ec2-user/SageMaker/blender-2.82a-linux64/2.82/python
# output: output
# theta: 180
# bucket: 3m-s3-data-sharing-bucket
# background: background.pck
# three_d_object: skidsteer.obj
# Info: Deleted 1 object(s)
# Info: Deleted 1 object(s)
# (  0.0000 sec |   0.0000 sec) Importing OBJ 'three_d_object.obj'...
#   (  0.0001 sec |   0.0001 sec) Parsing OBJ file...
# ^Cogress:   0.00%
#
# Sent an internal break event. Press ^C again to kill Blender

# %%
#To see logs of the container, run following command.
# !docker logs odin-container
# Out:
# Blender 2.82 (sub 7) (hash 375c7dc4caf4 built 2020-03-12 05:30:40)
# found bundled python: /blender-2.82a-linux64/2.82/python
# Info: Deleted 1 object(s)
# Fra:1 Mem:115.51M (0.00M, Peak 158.88M) | Time:00:00.08 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | text
# Fra:1 Mem:135.55M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# Fra:1 Mem:117.13M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Waiting for render to start
# Fra:1 Mem:117.15M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:117.15M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Scene
# Fra:1 Mem:117.15M (0.00M, Peak 183.57M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Updating Shaders
# ...
